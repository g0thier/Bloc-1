# %%
# Usuals imports 
import numpy as np
import pandas as pd 
import requests
from time import sleep

# %% [markdown]
# ## Cities

# %%
cities = ["Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris", "Amiens", "Lille", "Strasbourg", "Chateau du Haut Koenigsbourg", "Colmar", "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon", "Gorges du Verdon", "Bormes les Mimosas", "Cassis", "Marseille", "Aix en Provence", "Avignon", "Uzes", "Nimes", "Aigues Mortes", "Saintes Maries de la mer", "Collioure", "Carcassonne", "Ariege", "Toulouse", "Montauban", "Biarritz", "Bayonne", "La Rochelle"]

# %% [markdown]
# *   hotel name,
# *   Url to its booking.com page,
# *   Its coordinates: latitude and longitude
# *   Score given by the website users
# *   Text description of the hotel

# %%
# https://www.booking.com/searchresults.fr.html?
# ss=Paris%2C+Île-de-France%2C+France
# &label=gen173nr-1DCAQoggI49ANIDVgEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aq3-n5gGwAIB0gIkYWJmNWRjNTktNjUzZC00M2I3LTg3MzItN2IyZGE3YWE0NDU32AIE4AIB
# &sid=f42b0ce9b418c5ddef3c50ca6f7bacb1
# &aid=304142&lang=fr&sb=1
# &src_elem=sb
# &src=searchresults
# &dest_id=-1456928
# &dest_type=city
# &ac_position=0
# &ac_click_type=b
# &ac_langcode=fr
# &ac_suggestion_list_length=5
# &search_selected=true
# &search_pageview_id=ba89a1e1dfa70157
# &checkin=2022-08-26
# &checkout=2022-08-27
# &group_adults=2
# &no_rooms=1
# &group_children=0
# &sb_travel_purpose=leisure


https://www.booking.com/searchresults.fr.html?
aid=304142
&label=gen173nr-1DCAQoggI49ANIDVgEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aq3-n5gGwAIB0gIkYWJmNWRjNTktNjUzZC00M2I3LTg3MzItN2IyZGE3YWE0NDU32AIE4AIB
&sid=92af1df473e22328937c110555b71e87
&sb=1
&sb_lp=1
&src=index
&src_elem=sb
&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Faid%3D304142%26label%3Dgen173nr-1DCAQoggI49ANIDVgEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aq3-n5gGwAIB0gIkYWJmNWRjNTktNjUzZC00M2I3LTg3MzItN2IyZGE3YWE0NDU32AIE4AIB%26sid%3D92af1df473e22328937c110555b71e87%26sb_price_type%3Dtotal%26%26
&ss=Paris
&is_ski_area=0
&ssne=Paris
&ssne_untouched=Paris
&dest_id=-1456928
&dest_type=city
&checkin_year=2022
&checkin_month=8
&checkin_monthday=26
&checkout_year=2022
&checkout_month=8
&checkout_monthday=27
&group_adults=2
&group_children=0
&no_rooms=1
&b_h4u_keep_filters=
&from_sf=1

https://www.booking.com/searchresults.fr.html?aid=304142&label=gen173nr-1DCAQoggI49ANIDVgEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aq3-n5gGwAIB0gIkYWJmNWRjNTktNjUzZC00M2I3LTg3MzItN2IyZGE3YWE0NDU32AIE4AIB&sid=92af1df473e22328937c110555b71e87&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Faid%3D304142%26label%3Dgen173nr-1DCAQoggI49ANIDVgEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aq3-n5gGwAIB0gIkYWJmNWRjNTktNjUzZC00M2I3LTg3MzItN2IyZGE3YWE0NDU32AIE4AIB%26sid%3D92af1df473e22328937c110555b71e87%26sb_price_type%3Dtotal%26%26&ss=Paris&is_ski_area=0&ssne=Paris&ssne_untouched=Paris&dest_id=-1456928&dest_type=city&checkin_year=2022&checkin_month=8&checkin_monthday=26&checkout_year=2022&checkout_month=8&checkout_monthday=27&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1
https://www.booking.com/searchresults.fr.html?label=gen173nr-1DCAQoggI49ANIDVgEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aq3-n5gGwAIB0gIkYWJmNWRjNTktNjUzZC00M2I3LTg3MzItN2IyZGE3YWE0NDU32AIE4AIB&sid=92af1df473e22328937c110555b71e87&aid=304142&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Faid%3D304142%26label%3Dgen173nr-1DCAQoggI49ANIDVgEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aq3-n5gGwAIB0gIkYWJmNWRjNTktNjUzZC00M2I3LTg3MzItN2IyZGE3YWE0NDU32AIE4AIB%26sid%3D92af1df473e22328937c110555b71e87%26sb_price_type%3Dtotal%26%26&ss=Paris&is_ski_area=0&ssne=Paris&ssne_untouched=Paris&dest_id=-1456928&dest_type=city&checkin_year=2022&checkin_month=8&checkin_monthday=26&checkout_year=2022&checkout_month=8&checkout_monthday=27&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1

&offset=975

fonctionne de 25 en 25 

https://www.booking.com/searchresults.fr.html?ss=Paris%2C+Île-de-France%2C+France&ssne=Marseille&ssne_untouched=Marseille&label=gen173nr-1DCAQoggI49ANIDVgEaE2IAQGYAQ24AQfIAQ3YAQPoAQH4AQOIAgGoAgO4Aq3-n5gGwAIB0gIkYWJmNWRjNTktNjUzZC00M2I3LTg3MzItN2IyZGE3YWE0NDU32AIE4AIB&sid=92af1df473e22328937c110555b71e87&aid=304142&lang=fr&sb=1&src_elem=sb&src=searchresults&dest_id=-1456928&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=fr&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=d529a45d903001fc&checkin=2022-08-26&checkout=2022-08-27&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure

<h1 class="e1f827110f d3a14d00da">Paris&nbsp;: 1 244 établissements trouvés</h1>

<h1 class="e1f827110f d3a14d00da">Marseille&nbsp;: 132 établissements trouvés</h1>

# %%
# Creating urls params
ss = 'Paris%2C+Île-de-France%2C+France'
ac_langcode = 'fr'
dest_type = 'city'
checkin = '2022-08-26'
checkout = '2022-08-27'

payload = {'ss': ss, 'ac_langcode': ac_langcode, 'dest_type': dest_type, 'checkin': checkin, 'checkout': checkout}

# Create the requests 
r = requests.get('https://www.booking.com/searchresults.fr.html?', params= payload)

print(r.status_code)

if r.status_code == 200 :
        print(r.content)
# Out:
# 200
# ...

# %% [markdown]
# ## Goals 🎯
#
# As the project has just started, your team doesn't have any data that can be used to create this application. Therefore, your job will be to:
#
# * √ Scrape data from destinations
# * √ Get weather data from each destination
# * Get hotels' info about each destination
# * Store all the information above in a data lake
# * Extract, transform and load cleaned data from your datalake to a data warehouse
